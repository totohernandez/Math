# %% [markdown]
# # Vectors
#
# ## Types of vectors
#
# ### Geometric Vectors
#
# Geometric vectors are oriented segments. Many linear algebra concepts como from geometric point of view of vector: space, plane, distance, etc.
#
# ![image.png](attachment:image.png)
#
# ### Polynomials
#
# A polynomial is an expression like $f(x)=x2+y+1$. This is, a expresion adding multiple "terms" (nomials). Polyomials are vectors because they meet the definition of a vector: they can be added together to get another polynomial, and they can be multiplied together to get another polynomial.
#
# $f(x)+g(x)$
#
# $5×f(x)$
#
# ![image-2.png](attachment:image-2.png)
#
# ### Elements of R
#
# Elements of $\mathbb{R}^{''}$ are sets of real numbers. It is commonly how data is represented in computers to build machine learning models.
#
# $$ X = \begin{bmatrix}X_1\\X_2\\X_3\end{bmatrix} \in \mathbb{R}^{''}$$
#
# Addition is valid
#
# $$\begin{bmatrix}1\\2\\3\end{bmatrix} + \begin{bmatrix}1\\2\\3\end{bmatrix} = \begin{bmatrix}2\\4\\6\end{bmatrix}$$
#
# Multiplication is valid
#
# $$5 x \begin{bmatrix}1\\2\\3\end{bmatrix} = \begin{bmatrix}5\\10\\15\end{bmatrix}$$
#
# Vector addition has a series of fundamental properties worth mentioning:
#
# ### Zero Vector
#
# Vectors composed of zeros, and zeros only.
#
# $$ 0 = \begin{bmatrix}0\\0\\0\end{bmatrix} $$
#
# ### Unit Vector
#
# ### Sparse Vector
#
# Commutativity: x+y=y+x
# Associativity: (x+y)+z=x+(y+z)
# Adding the zero vector has no effect: x+0=0+x=x
# Substracting a vector from itself returns the zero vector: x−x=0

# %%
import numpy as np
import pandas as pd

# %%
x = np.array([[1],
             [2],
             [3]])
x.shape
# Out:
# (3, 1)

# %%
print(f'A 3-dimensional vector:\n{x}')
# Out:
# A 3-dimensional vector:
# [[1]
#  [2]
#  [3]]

# %%
x = y = np.array([[1],
                 [2],
                 [3]])
x + y
# Out:
# array([[2],
#        [4],
#        [6]])

# %%
np.add(x,y)
# Out:
# array([[2],
#        [4],
#        [6]])

# %%
alpha = 2
x = np.array([[1],
            [2],
            [3]])

alpha * x
# Out:
# array([[2],
#        [4],
#        [6]])

# %%
a, b = 2, 3 
x, y = np.array([[2],[3]]), np.array([[4],[5]])

a*x + b*y
# Out:
# array([[16],
#        [21]])

# %%
x, y = np.array([[-2],[2]]), np.array([[4],[-3]])

#Transpose vector x with @ operator
x.T @ y
# Out:
# array([[-14]])
